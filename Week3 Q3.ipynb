# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
! pip install beautifulsoup4
from bs4 import BeautifulSoup
import requests
import pandas as pd
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from beautifulsoup4) (2.2.1)

# %% [markdown]
# #instal soup

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
request= requests.get(url).text

# %%
soup = BeautifulSoup(request, 'html.parser')

# %% [markdown]
# use html.parser

# %%
column_names = ['Postal code','Borough','Neighborhood']
df=pd.DataFrame(columns=column_names)

# %% [markdown]
# select column names

# %%
table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):  #there is information in 'td'
    cell = {} 
    if row.span.text=='Not assigned':  #skip not assigned postal code text
        pass  
    else:
        cell['Postal Code'] = row.p.text[:3]  #first 3 character is postal code
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ') #remove ( and connect text with ","
        table_contents.append(cell)

df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})

# %%
df.shape[0]
# Out:
# 103

# %%
df.head()
# Out:
#   Postal Code           Borough                      Neighborhood
# 0         M3A        North York                         Parkwoods
# 1         M4A        North York                  Victoria Village
# 2         M5A  Downtown Toronto         Regent Park, Harbourfront
# 3         M6A        North York  Lawrence Manor, Lawrence Heights
# 4         M7A      Queen's Park     Ontario Provincial Government

# %% [markdown]
# same as Q1 util now

# %%
postal_code="M5G"

# %%
! pip install geocoder
postal_code="M5G"
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (8.0.1)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.25.1)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.16.0)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from click->geocoder) (4.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (4.0.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: zipp>=0.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click->geocoder) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->click->geocoder) (3.7.4.3)

# %%
import geocoder # import geocoder

# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates
while(lat_lng_coords is None):
  g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
  lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-15d80b1bb123> in <module>
#       6 # loop until you get the coordinates
#       7 while(lat_lng_coords is None):
# ----> 8   g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
#       9   lat_lng_coords = g.latlng
#      10
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# <decorator-gen-128> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# ~/conda/envs/python/lib/python3.6/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# <decorator-gen-127> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# ~/conda/envs/python/lib/python3.6/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      36
#      37         self.__numcalls += 1
# ---> 38         return f(*args, **kwargs)
#      39
#      40     def __call__(self, f, *args, **kwargs):
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/google.py in rate_limited_get_for_dev(self, *args, **kwargs)
#     272     @ratelim.greedy(10, 1)
#     273     def rate_limited_get_for_dev(self, *args, **kwargs):
# --> 274         return super(GoogleQuery, self).rate_limited_get(*args, **kwargs)
#     275
#     276     @ratelim.greedy(100000, 60 * 60 * 24)  # Google for Work daily limit
#
# ~/conda/envs/python/lib/python3.6/site-packages/geocoder/base.py in rate_limited_get(self, url, **kwargs)
#     508     def rate_limited_get(self, url, **kwargs):
#     509         """ By default, simply wraps a session.get request"""
# --> 510         return self.session.get(url, **kwargs)
#     511
#     512     def _adapt_results(self, json_response):
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     419             server_hostname=server_hostname,
#     420             ssl_context=context,
# --> 421             tls_in_tls=tls_in_tls,
#     422         )
#     423
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400     if ca_certs or ca_cert_dir or ca_cert_data:
#     401         try:
# --> 402             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403         except (IOError, OSError) as e:
#     404             raise SSLError(e)
#
# KeyboardInterrupt:

# %% [markdown]
# LOAD CSV

# %%
url2="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv"

# %%
df2=pd.read_csv(url2)

# %%
df_merge=pd.merge(df,df2,on="Postal Code")

# %%
df_merge.head()
# Out:
#   Postal Code           Borough                      Neighborhood   Latitude  \
# 0         M3A        North York                         Parkwoods  43.753259
# 1         M4A        North York                  Victoria Village  43.725882
# 2         M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3         M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4         M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
df_Toronto=df_merge[df_merge['Borough'].str.contains('Toronto')]

# %%
df_Toronto=df_Toronto.reset_index(drop=True)

# %%
aa=df_Toronto["Neighborhood"].unique()
aa=pd.DataFrame(sorted(aa))
aa
# Out:
#                                                     0
# 0                                         Berczy Park
# 1        Brockton, Parkdale Village, Exhibition Place
# 2   CN Tower, King and Spadina, Railway Lands, Har...
# 3                                  Central Bay Street
# 4                                            Christie
# 5                                Church and Wellesley
# 6                      Commerce Court, Victoria Hotel
# 7                                          Davisville
# 8                                    Davisville North
# 9                        Dufferin, Dovercourt Village
# 10                                     Enclave of M4L
# 11                                     Enclave of M5E
# 12             First Canadian Place, Underground city
# 13                           Forest Hill North & West
# 14                           Garden District, Ryerson
# 15  Harbourfront East, Union Station, Toronto Islands
# 16                      High Park, The Junction South
# 17                     India Bazaar, The Beaches West
# 18          Kensington Market, Chinatown, Grange Park
# 19                                      Lawrence Park
# 20                           Little Portugal, Trinity
# 21                        Moore Park, Summerhill East
# 22                                 North Toronto West
# 23                             Parkdale, Roncesvalles
# 24                          Regent Park, Harbourfront
# 25                           Richmond, Adelaide, King
# 26                                           Rosedale
# 27                                           Roselawn
# 28                                 Runnymede, Swansea
# 29                                     St. James Town
# 30                        St. James Town, Cabbagetown
# 31                                    Studio District
# 32  Summerhill West, Rathnelly, South Hill, Forest...
# 33                The Annex, North Midtown, Yorkville
# 34                                        The Beaches
# 35                                 The Danforth  East
# 36                       The Danforth West, Riverdale
# 37           Toronto Dominion Centre, Design Exchange
# 38                     University of Toronto, Harbord

# %%
bb=T_OH_group.index
bb=pd.DataFrame(sorted(bb))
bb
# Out:
#                                                     0
# 0                                         Berczy Park
# 1        Brockton, Parkdale Village, Exhibition Place
# 2   CN Tower, King and Spadina, Railway Lands, Har...
# 3                                  Central Bay Street
# 4                                            Christie
# 5                                Church and Wellesley
# 6                      Commerce Court, Victoria Hotel
# 7                                          Davisville
# 8                                    Davisville North
# 9                        Dufferin, Dovercourt Village
# 10                                     Enclave of M4L
# 11                                     Enclave of M5E
# 12             First Canadian Place, Underground city
# 13                           Forest Hill North & West
# 14                           Garden District, Ryerson
# 15  Harbourfront East, Union Station, Toronto Islands
# 16                      High Park, The Junction South
# 17                     India Bazaar, The Beaches West
# 18          Kensington Market, Chinatown, Grange Park
# 19                                      Lawrence Park
# 20                           Little Portugal, Trinity
# 21                                 North Toronto West
# 22                             Parkdale, Roncesvalles
# 23                          Regent Park, Harbourfront
# 24                           Richmond, Adelaide, King
# 25                                           Rosedale
# 26                                           Roselawn
# 27                                 Runnymede, Swansea
# 28                                     St. James Town
# 29                        St. James Town, Cabbagetown
# 30                                    Studio District
# 31  Summerhill West, Rathnelly, South Hill, Forest...
# 32                The Annex, North Midtown, Yorkville
# 33                                        The Beaches
# 34                                 The Danforth  East
# 35                       The Danforth West, Riverdale
# 36           Toronto Dominion Centre, Design Exchange
# 37                     University of Toronto, Harbord

# %% [markdown]
# USE data only contain "Toronto" in Borough

# %% [markdown]
# get address of toronto

# %%
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of New York City are 43.6534817, -79.3839347.

# %% [markdown]
# CLIENT_ID = 'OZGTEVWYBTM3S2QI0LTIW3G4SRR3KJ45TC255JCRJMRRXBYD' # your Foursquare ID
# CLIENT_SECRET = 'K2TW3JJ5LRB4FHZ5SF2MVBQZ0MVYV5IEQGUH2NGEEMMM215S' # your Foursquare Secret
# ACCESS_TOKEN = 'FPG1QR51MSXLF5UTJNKZOUEAAPMCOR500TT3SUFLYNWOCJHT' Get information nearby Toronto

# %%
CLIENT_ID = 'OZGTEVWYBTM3S2QI0LTIW3G4SRR3KJ45TC255JCRJMRRXBYD' # your Foursquare ID
CLIENT_SECRET = 'K2TW3JJ5LRB4FHZ5SF2MVBQZ0MVYV5IEQGUH2NGEEMMM215S' # your Foursquare Secret
ACCESS_TOKEN = 'FPG1QR51MSXLF5UTJNKZOUEAAPMCOR500TT3SUFLYNWOCJHT' 
VERSION = '20180605' # Foursquare API version
LIMIT = 77 # A default Foursquare API limit value

# %% [markdown]
# Using API, bring a variety of map data near neighborhood.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
      
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Toronto_venues = getNearbyVenues(names=df_Toronto['Neighborhood'],
                                   latitudes=df_Toronto['Latitude'],
                                   longitudes=df_Toronto['Longitude'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-372-a31a23c4743b> in <module>
#       1 Toronto_venues = getNearbyVenues(names=df_Toronto['Neighborhood'],
#       2                                    latitudes=df_Toronto['Latitude'],
# ----> 3                                    longitudes=df_Toronto['Longitude'])
#
# <ipython-input-32-e704418279fb> in getNearbyVenues(names, latitudes, longitudes, radius)
#      16
#      17         # make the GET request
# ---> 18         results = requests.get(url).json()["response"]['groups'][0]['items']
#      19
#      20         # return only relevant information for each nearby venue
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/conda/envs/python/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     704                 body=body,
#     705                 headers=headers,
# --> 706                 chunked=chunked,
#     707             )
#     708
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/conda/envs/python/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/conda/envs/python/lib/python3.6/http/client.py in getresponse(self)
#    1377         try:
#    1378             try:
# -> 1379                 response.begin()
#    1380             except ConnectionError:
#    1381                 self.close()
#
# ~/conda/envs/python/lib/python3.6/http/client.py in begin(self)
#     309         # read until we get a non-100 response
#     310         while True:
# --> 311             version, status, reason = self._read_status()
#     312             if status != CONTINUE:
#     313                 break
#
# ~/conda/envs/python/lib/python3.6/http/client.py in _read_status(self)
#     270
#     271     def _read_status(self):
# --> 272         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     273         if len(line) > _MAXLINE:
#     274             raise LineTooLong("status line")
#
# ~/conda/envs/python/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/conda/envs/python/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/conda/envs/python/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/conda/envs/python/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# one hot encode with get_dimmies

# %%
T_OH=pd.get_dummies(Toronto_venues[["Venue Category"]],prefix="", prefix_sep="")
T_OH.drop("Neighborhood",axis=1,inplace=True)
T_OH.insert(0,"Neighborhood",Toronto_venues["Neighborhood"])
T_OH.shape
# Out:
# (1333, 213)

# %%
T_OH_group=T_OH.groupby("Neighborhood").mean()

# %% [markdown]
# Find Group!!

# %%
T_OH_group.index
# Out:
# Index(['Berczy Park', 'Brockton, Parkdale Village, Exhibition Place',
#        'CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport',
#        'Central Bay Street', 'Christie', 'Church and Wellesley',
#        'Commerce Court, Victoria Hotel', 'Davisville', 'Davisville North',
#        'Dufferin, Dovercourt Village', 'Enclave of M4L', 'Enclave of M5E',
#        'First Canadian Place, Underground city', 'Forest Hill North & West',
#        'Garden District, Ryerson',
#        'Harbourfront East, Union Station, Toronto Islands',
#        'High Park, The Junction South', 'India Bazaar, The Beaches West',
#        'Kensington Market, Chinatown, Grange Park', 'Lawrence Park',
#        'Little Portugal, Trinity', 'North Toronto West',
#        'Parkdale, Roncesvalles', 'Regent Park, Harbourfront',
#        'Richmond, Adelaide, King', 'Rosedale', 'Roselawn',
#        'Runnymede, Swansea', 'St. James Town', 'St. James Town, Cabbagetown',
#        'Studio District',
#        'Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park',
#        'The Annex, North Midtown, Yorkville', 'The Beaches',
#        'The Danforth  East', 'The Danforth West, Riverdale',
#        'Toronto Dominion Centre, Design Exchange',
#        'University of Toronto, Harbord'],
#       dtype='object', name='Neighborhood')

# %%
del(Top11)
Top11=pd.DataFrame(columns=["first","second","third","forth",'fifth','6th','7th','8th','9th','10th','11th'])
Top11
# Out:
# Empty DataFrame
# Columns: [first, second, third, forth, fifth, 6th, 7th, 8th, 9th, 10th, 11th]
# Index: []

# %% [markdown]
# select only top 11 data.

# %%
#Top11["Neighborhood"]=T_OH_group.T.columns
for i in range(len(T_OH_group.T.columns)):
   
    a=T_OH_group.T.iloc[:,i].sort_values(ascending=False).head(11)
    Top11.loc[len(Top11)]=a.index.values
   
Top11.loc[:,"Neighborhood"]=T_OH_group.T.columns    

fixed_columns = [Top11.columns[-1]] + list(Top11.columns[:-1])
Top11 = Top11[fixed_columns]

# %%
Top11.head()
# Out:
#                                         Neighborhood            first  \
# 0                                        Berczy Park     Cocktail Bar
# 1       Brockton, Parkdale Village, Exhibition Place             Café
# 2  CN Tower, King and Spadina, Railway Lands, Har...  Airport Service
# 3                                 Central Bay Street      Coffee Shop
# 4                                           Christie    Grocery Store
#
#              second             third               forth  \
# 0    Sandwich Place            Bakery         Coffee Shop
# 1            Bakery    Sandwich Place      Breakfast Spot
# 2  Airport Terminal             Plane    Sculpture Garden
# 3    Sandwich Place  Sushi Restaurant  Italian Restaurant
# 4              Café              Park          Baby Store
#
#                            fifth                 6th             7th  \
# 0  Vegetarian / Vegan Restaurant  Seafood Restaurant  Farmers Market
# 1                    Coffee Shop          Restaurant       Nightclub
# 2                        Airport  Airport Food Court    Airport Gate
# 3            Japanese Restaurant                Café            Bank
# 4             Italian Restaurant           Nightclub      Restaurant
#
#                    8th                 9th                10th  \
# 0             Beer Bar              Museum  Italian Restaurant
# 1  Japanese Restaurant  Italian Restaurant        Intersection
# 2       Airport Lounge       Boat or Ferry     Harbor / Marina
# 3          Salad Place         Pizza Place          Restaurant
# 4          Coffee Shop    Airport Terminal    Department Store
#
#                   11th
# 0   Basketball Stadium
# 1                  Bar
# 2  Rental Car Location
# 3         Burger Joint
# 4          Escape Room

# %% [markdown]
# Reset index to become pretty

# %%
Top11.reset_index(drop=True,inplace=True)

# %%
kclusters = 6

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(T_OH_group)
kmeans.labels_[0:10]
# Out:
# array([2, 2, 1, 2, 2, 2, 2, 2, 1, 2], dtype=int32)

# %% [markdown]
# i merege two dataframe. it is easy to understand

# %%
Top11.insert(0, 'Cluster Labels', kmeans.labels_)

Torronto_merged = df_Toronto

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
Torronto_merged = Torronto_merged.join(Top11.set_index('Neighborhood'), on='Neighborhood')

# %%
df_Toronto=df_Toronto[df_Toronto["Neighborhood"]!="Moore Park, Summerhill East"] #because of error i delet this area

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(Torronto_merged['Latitude'], Torronto_merged['Longitude'], Torronto_merged['Neighborhood'], Torronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_ba645b7376e5436aaa74e020d30723df%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ba645b7376e5436aaa74e020d30723df%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ba645b7376e5436aaa74e020d30723df%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_ba645b7376e5436aaa74e020d30723df%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
Torronto_merged.loc[Torronto_merged['Cluster Labels'] == 0, Torronto_merged.columns[[1] + list(range(5, Torronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels first         second  third  \
# 21   Central Toronto               0  Park  Jewelry Store  Trail
# 33  Downtown Toronto               0  Park     Playground  Trail
#
#                forth                        fifth           6th  \
# 21  Sushi Restaurant                  Yoga Studio  Dance Studio
# 33      Cupcake Shop  Eastern European Restaurant    Donut Shop
#
#                  7th               8th                  9th  \
# 21        Donut Shop  Doner Restaurant              Dog Run
# 33  Doner Restaurant           Dog Run  Distribution Center
#
#                    10th            11th
# 21  Distribution Center  Discount Store
# 33       Discount Store           Diner

# %%
label 1 group
it has cafe, cocktail bar in common

# %%
Torronto_merged.loc[Torronto_merged['Cluster Labels'] == 1, Torronto_merged.columns[[1] + list(range(5, Torronto_merged.shape[1]))]]
# Out:
#                   Borough  Cluster Labels               first  \
# 3            East Toronto               1                Park
# 15           East Toronto               1      Sandwich Place
# 20        Central Toronto               1                Park
# 32       Downtown Toronto               1     Airport Service
# 38  East Toronto Business               1  Light Rail Station
#
#                   second              third              forth  \
# 3                  Trail  Health Food Store                Pub
# 15  Fast Food Restaurant               Park  Food & Drink Shop
# 20  Gym / Fitness Center     Sandwich Place     Breakfast Spot
# 32      Airport Terminal              Plane   Sculpture Garden
# 38           Pizza Place         Smoke Shop         Restaurant
#
#                fifth                 6th                   7th  \
# 3   Asian Restaurant        Cupcake Shop            Donut Shop
# 15      Liquor Store          Restaurant               Brewery
# 20        Playground    Department Store                 Hotel
# 32           Airport  Airport Food Court          Airport Gate
# 38           Brewery      Farmers Market  Fast Food Restaurant
#
#                    8th            9th                 10th  \
# 3     Doner Restaurant        Dog Run  Distribution Center
# 15  Italian Restaurant            Pub        Burrito Place
# 20   Food & Drink Shop   Cupcake Shop              Dog Run
# 32      Airport Lounge  Boat or Ferry      Harbor / Marina
# 38       Burrito Place  Auto Workshop           Skate Park
#
#                    11th
# 3        Discount Store
# 15           Steakhouse
# 20  Distribution Center
# 32  Rental Car Location
# 38        Garden Center

# %%
label 2 group
it has cafe, cocktail bar in common

# %%
Torronto_merged.loc[Torronto_merged['Cluster Labels'] == 2, Torronto_merged.columns[[1] + list(range(5, Torronto_merged.shape[1]))]]
# Out:
#                    Borough  Cluster Labels             first  \
# 0         Downtown Toronto               2       Coffee Shop
# 1         Downtown Toronto               2       Coffee Shop
# 2         Downtown Toronto               2       Coffee Shop
# 4         Downtown Toronto               2      Cocktail Bar
# 5         Downtown Toronto               2       Coffee Shop
# 6         Downtown Toronto               2     Grocery Store
# 7         Downtown Toronto               2       Coffee Shop
# 8             West Toronto               2              Pool
# 10        Downtown Toronto               2       Coffee Shop
# 11            West Toronto               2               Bar
# 12            East Toronto               2  Greek Restaurant
# 13        Downtown Toronto               2       Coffee Shop
# 14            West Toronto               2              Café
# 16        Downtown Toronto               2       Coffee Shop
# 17            East Toronto               2       Coffee Shop
# 22            West Toronto               2              Café
# 23         Central Toronto               2       Coffee Shop
# 24         Central Toronto               2    Sandwich Place
# 25            West Toronto               2       Coffee Shop
# 26         Central Toronto               2    Sandwich Place
# 27        Downtown Toronto               2              Café
# 28            West Toronto               2       Coffee Shop
# 30        Downtown Toronto               2              Café
# 31         Central Toronto               2       Coffee Shop
# 34  Downtown Toronto Stn A               2    Sandwich Place
# 35        Downtown Toronto               2       Coffee Shop
# 36        Downtown Toronto               2       Coffee Shop
# 37        Downtown Toronto               2  Sushi Restaurant
#
#                            second               third  \
# 0                             Pub                Park
# 1                  Sandwich Place                Café
# 2                            Café        Cocktail Bar
# 4                  Sandwich Place              Bakery
# 5                  Sandwich Place    Sushi Restaurant
# 6                            Café                Park
# 7                            Café      Sandwich Place
# 8                        Pharmacy                Bank
# 10                           Café            Aquarium
# 11          Vietnamese Restaurant         Coffee Shop
# 12             Italian Restaurant         Coffee Shop
# 13                           Café               Hotel
# 14                         Bakery      Sandwich Place
# 16                           Café          Restaurant
# 17                           Café           Gastropub
# 22                            Bar  Mexican Restaurant
# 23                 Clothing Store                Café
# 24                           Café         Coffee Shop
# 25                 Breakfast Spot       Movie Theater
# 26                   Dessert Shop         Coffee Shop
# 27                    Coffee Shop      Sandwich Place
# 28                            Pub         Pizza Place
# 30  Vegetarian / Vegan Restaurant         Coffee Shop
# 31            American Restaurant          Bagel Shop
# 34                    Coffee Shop        Cocktail Bar
# 35                           Café         Pizza Place
# 36                           Café      Sandwich Place
# 37            Japanese Restaurant         Coffee Shop
#
#                             forth                          fifth  \
# 0                          Bakery                     Restaurant
# 1                  Clothing Store                           Bank
# 2              Italian Restaurant                     Restaurant
# 4                     Coffee Shop  Vegetarian / Vegan Restaurant
# 5              Italian Restaurant            Japanese Restaurant
# 6                      Baby Store             Italian Restaurant
# 7                Sushi Restaurant                     Restaurant
# 8                     Supermarket                            Bar
# 10                          Hotel                 Sandwich Place
# 11  Vegetarian / Vegan Restaurant        New American Restaurant
# 12                 Ice Cream Shop               Sushi Restaurant
# 13                  Deli / Bodega            Japanese Restaurant
# 14                 Breakfast Spot                    Coffee Shop
# 16                            Gym                          Hotel
# 17                         Bakery                    Cheese Shop
# 22                Thai Restaurant           Fast Food Restaurant
# 23                          Diner                     Restaurant
# 24                 History Museum                   Liquor Store
# 25                     Restaurant                           Bank
# 26               Sushi Restaurant                    Pizza Place
# 27            Japanese Restaurant                            Bar
# 28                           Café               Sushi Restaurant
# 30            Arts & Crafts Store             Mexican Restaurant
# 31                           Bank                    Pizza Place
# 34                       Beer Bar                          Hotel
# 35                         Bakery             Italian Restaurant
# 36            Japanese Restaurant                            Gym
# 37                     Restaurant                        Gay Bar
#
#                           6th                   7th                   8th  \
# 0                        Café                 Hotel                   Spa
# 1                       Hotel   Japanese Restaurant        Cosmetics Shop
# 2              Clothing Store   American Restaurant              Beer Bar
# 4          Seafood Restaurant        Farmers Market              Beer Bar
# 5                        Café                  Bank           Salad Place
# 6                   Nightclub            Restaurant           Coffee Shop
# 7                         Gym         Deli / Bodega            Steakhouse
# 8   Middle Eastern Restaurant           Art Gallery                Bakery
# 10                 Restaurant            Sports Bar   Sporting Goods Shop
# 11           Asian Restaurant                  Café           Yoga Studio
# 12                 Restaurant                   Spa     Indian Restaurant
# 13                 Restaurant           Salad Place        Sandwich Place
# 14                 Restaurant             Nightclub   Japanese Restaurant
# 16        Japanese Restaurant        Sandwich Place         Deli / Bodega
# 17                Fish Market                   Bar                  Bank
# 22                  Speakeasy                 Diner    Italian Restaurant
# 23                        Spa   Sporting Goods Shop  Fast Food Restaurant
# 24  Middle Eastern Restaurant     Indian Restaurant                   Pub
# 25                        Bar      Cuban Restaurant          Dessert Shop
# 26                        Gym              Pharmacy                 Diner
# 27                        Pub                Bakery                   Gym
# 28         Italian Restaurant           Yoga Studio     Health Food Store
# 30      Vietnamese Restaurant           Gaming Cafe                   Bar
# 31      Vietnamese Restaurant    Light Rail Station      Sushi Restaurant
# 34        Japanese Restaurant                  Bank    Italian Restaurant
# 35                        Pub            Restaurant                 Diner
# 36                      Hotel            Restaurant      Sushi Restaurant
# 37   Mediterranean Restaurant  Fast Food Restaurant     Indian Restaurant
#
#                           9th                       10th  \
# 0              Farmers Market                 Beer Store
# 1   Middle Eastern Restaurant            Thai Restaurant
# 2              Cosmetics Shop                        Gym
# 4                      Museum         Italian Restaurant
# 5                 Pizza Place                 Restaurant
# 6            Airport Terminal           Department Store
# 7                       Hotel               Concert Hall
# 8                        Café                    Brewery
# 10                Pizza Place                    Brewery
# 11                      Diner         Italian Restaurant
# 12        Japanese Restaurant             Sandwich Place
# 13                        Gym           Sushi Restaurant
# 14         Italian Restaurant               Intersection
# 16               Cocktail Bar                  Gastropub
# 17           Stationery Store             Ice Cream Shop
# 22                     Bakery  Cajun / Creole Restaurant
# 23                 Bagel Shop             Ice Cream Shop
# 24                  BBQ Joint                       Park
# 25                    Dog Run             Clothing Store
# 26         Seafood Restaurant                    Brewery
# 27         Italian Restaurant                   Beer Bar
# 28  Latin American Restaurant        Indie Movie Theater
# 30               Burger Joint                     Bakery
# 31                 Donut Shop           Doner Restaurant
# 34                     Bakery                       Café
# 35        Japanese Restaurant                 Beer Store
# 36              Deli / Bodega               Concert Hall
# 37               Dance Studio                        Pub
#
#                            11th
# 0                Sandwich Place
# 1                   Pizza Place
# 2           Japanese Restaurant
# 4            Basketball Stadium
# 5                  Burger Joint
# 6                   Escape Room
# 7                   Pizza Place
# 8                  Liquor Store
# 10               Scenic Lookout
# 11          Japanese Restaurant
# 12                    Juice Bar
# 13                       Lounge
# 14                          Bar
# 16          American Restaurant
# 17    Latin American Restaurant
# 22          Fried Chicken Joint
# 23                    Pet Store
# 24                  Pizza Place
# 25  Eastern European Restaurant
# 26           Italian Restaurant
# 27                   Beer Store
# 28                  IT Services
# 30                  Record Shop
# 31                      Dog Run
# 34                          Gym
# 35                  Snack Place
# 36                   Steakhouse
# 37                Burrito Place

# %%
Torronto_merged.loc[Torronto_merged['Cluster Labels'] == 3, Torronto_merged.columns[[1] + list(range(5, Torronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels                    first        second  \
# 19  Central Toronto               3  Health & Beauty Service  Home Service
#
#      third        forth          fifth                6th  \
# 19  Garden  Yoga Studio  Deli / Bodega  Electronics Store
#
#                             7th         8th               9th     10th  \
# 19  Eastern European Restaurant  Donut Shop  Doner Restaurant  Dog Run
#
#                    11th
# 19  Distribution Center

# %%
Torronto_merged.loc[Torronto_merged['Cluster Labels'] == 4, Torronto_merged.columns[[1] + list(range(5, Torronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels first       second     third  \
# 18  Central Toronto               4  Park  Swim School  Bus Line
#
#                 forth                        fifth         6th  \
# 18  Electronics Store  Eastern European Restaurant  Donut Shop
#
#                  7th      8th                  9th            10th   11th
# 18  Doner Restaurant  Dog Run  Distribution Center  Discount Store  Diner

# %%
Torronto_merged.loc[Torronto_merged['Cluster Labels'] == 5, Torronto_merged.columns[[1] + list(range(5, Torronto_merged.shape[1]))]]
# Out:
#                   Borough  Cluster Labels first             second  \
# 9  East York/East Toronto               5  Park  Convenience Store
#
#          third         forth                        fifth         6th  \
# 9  Yoga Studio  Dance Studio  Eastern European Restaurant  Donut Shop
#
#                 7th      8th                  9th            10th   11th
# 9  Doner Restaurant  Dog Run  Distribution Center  Discount Store  Diner
